# %%
import numpy as np
import matplotlib.pyplot as plt
from tabula import read_pdf
df = read_pdf('https://images.zensho.co.jp/materials/hama-sushi/allergen/allergen.pdf',pages='all',multiple_tables=True,lattice=True)
df
# Out:
# Got stderr: Mar 31, 2024 8:39:22 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Mar 31, 2024 8:39:22 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# [                        商品名  通常\r1皿\rkcal 半\rシャリ\r1皿\rkcal     乳    卵 小\r麦  \
#  0                       NaN           NaN              NaN   NaN  NaN  NaN
#  1                       NaN           NaN              NaN   NaN  NaN  NaN
#  2                      一本穴子         155.0                -   NaN  NaN    ●
#  3                サーモンいくらつつみ         109.0                -   NaN  NaN    ●
#  4                 ほたていくらつつみ          65.0                -   NaN  NaN    ●
#  5                 大切り黒毛和牛握り         100.0               86     ●    ●    ●
#  6               炙り大切り黒毛和牛握り         102.0               88     ●    ●    ●
# ...

# %%
df[0].columns
# Out:
# Index(['商品名', '通常\r1皿\rkcal', '半\rシャリ\r1皿\rkcal', '乳', '卵', '小\r麦', 'そ\rば',
#        '(落\rピ 花\rー生\rナ\rッ\rツ\r)', '海\r老', 'か\rに', 'あ\rわ\rび', 'い\rか', 'い\rく\rら',
#        'さ\rけ', 'さ\rば', '牛\r肉', '鶏\r肉', '豚\r肉', 'ゼ\rラ\rチ\rン', 'オ\rレ\rン\rジ',
#        'キ\rウ\rイ\rフ\rル\rー\rツ', 'く\rる\rみ', 'バ\rナ\rナ', 'も\rも', 'り\rん\rご', '大\r豆',
#        '松\r茸', 'や\rま\rい\rも', 'ご\rま', 'カ\rシ\rュ\rー\rナ\rッ\rツ', 'ア\rー\rモ\rン\rド'],
#       dtype='object')

# %%
takhalal = []
for i in range(np.size(df)):
    df_page = df[i]
    beef = df_page['商品名']['●' == df_page['牛\r肉']]
    chicken = df_page['商品名']['●' == df_page['鶏\r肉']]
    pork = df_page['商品名']['●' == df_page['豚\r肉']]
    gelatine = df_page['商品名']['●' == df_page['ゼ\rラ\rチ\rン']]
    combined_array = np.concatenate((beef,chicken,pork,gelatine))
    unique_variables = np.unique(combined_array)
    for j in range(np.size(unique_variables)):
        takhalal.append(unique_variables[j])
# Out:
# /Users/hakaseh/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
for i in range(np.size(takhalal)):
    print(takhalal[i])
# Out:
# あぶりチーズ豚カルビ
# あぶり焼きはらす
# たまご焼き
# たらマヨ軍艦
# イベリコ豚の大とろ
# サラダ
# シーフードサラダ
# ハンバーグ
# 大切り焼きはらす(一貫)
# 旨だれ牛カルビ
# 明太とろろ軍艦
# 明太小柱軍艦
# 牛すき焼き風軍艦
# オニオンえび胡麻だれ
# オニオン豚カルビ胡麻だれ
# ミートボール
# 和牛ユッケ
# 大切りいか明太子(一貫)
# 焼きはらす
# 黒毛和牛にぎり(一貫)
# 7種の魚介 醤油らーめん
# 7種の魚介濃厚味噌らーめん
# Soyナゲット
# 【感動の丼】うな丼
# 【感動の丼】うな丼(飯プチ)
# 【感動の丼】えび天と季節の天丼
# 【感動の丼】特上うな丼
# 【感動の丼】特上うな丼(飯プチ)
# あさりバターうどん
# うなぎ茶碗蒸し
# えび天うどん
# おいもデラックス
# お出汁たこ焼き
# かにクリームコロッケ
# きつねうどん
# くら出汁たっぷりだし巻き
# すしやのシャリカレーうどん
# すしやのシャリカレーうどん(甘口)
# イタリアンティラミス
# イベリコ豚コロッケ
# カレーコロッケ
# ストロベリーアソート
# ビッくらポン!人気にぎりセット
# ビッくらポン!人気軍艦セット
# フライドチキン
# プリンタルト
# ミニころチキン
# ミルキーミルクレープ
# ミルクレープ
# ヨーグルトアイスケーキ(マンゴー)
# ヨーグルトアイスケーキ(桃)
# 伝説の鶏唐揚げ
# 和牛コロッケ
# 大学芋スティック
# 天然だしうどん
# 抹茶とあずきのケーキ
# 抹茶モンブランパフェ
# 揚げたて豆乳ドーナツ
# 本ズワイガニ茶碗蒸し
# 浜田チャーハン
# 牛カルビらーめん
# 特製かき揚げうどん
# 特製チャーシューコロッケ
# 特製茶碗蒸し
# 米粉のシフォンケーキ
# 胡麻香る担々麺
# 赤鶏ゆずうどん
# くら出汁
# ポン酢

# %%
df[5]
# Out:
# '活〆ぶり(四国・九州産)'
